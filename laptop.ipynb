# %%
import pandas as pd  # import pandas

# %%
df=pd.read_csv("laptopPrice.csv")     # read csv file 2 ways 
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.head() # bydefault to show top 5 rows
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.tail() # bydefault show last 5 rows
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 819  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 820  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 821  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 822   512 GB  0 GB      DOS  64-bit            0 GB  ThinNlight  No warranty
#
# ...

# %%
df.head(10) # top 10 rows show krengey
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8  Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9    acer             AMD        Ryzen 5            10th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# ...

# %%
df.tail(7)
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 816    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 817    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 816  1024 GB  0 GB  Windows  32-bit            6 GB      Casual  No warranty
# 817  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# ...

# %%
df.info() # total info btata h like column no.,non null count and their data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.dtypes  # data types of column btata h
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.describe()  # ye hume count,mean,std,min,max,25,50,75 % btata h
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.columns  # ye sare column btata h
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
cat_cloumn=df.select_dtypes(include="O")    # iisse hum sare categorical column ko nikal lete h 
cat_cloumn
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
num_column=df.select_dtypes(exclude="O") # isse hum numerical column ko nikalte h 
num_column
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [823 rows x 3 columns]

# %%
df1=cat_cloumn+num_column
df1
# Out:
#      Number of Ratings  Number of Reviews  Price Touchscreen brand  \
# 0                  NaN                NaN    NaN         NaN   NaN
# 1                  NaN                NaN    NaN         NaN   NaN
# 2                  NaN                NaN    NaN         NaN   NaN
# 3                  NaN                NaN    NaN         NaN   NaN
# 4                  NaN                NaN    NaN         NaN   NaN
# ..                 ...                ...    ...         ...   ...
# 818                NaN                NaN    NaN         NaN   NaN
# 819                NaN                NaN    NaN         NaN   NaN
# 820                NaN                NaN    NaN         NaN   NaN
# 821                NaN                NaN    NaN         NaN   NaN
# 822                NaN                NaN    NaN         NaN   NaN
#
#     graphic_card_gb  hdd msoffice   os os_bit processor_brand processor_gnrtn  \
# 0               NaN  NaN      NaN  NaN    NaN             NaN             NaN
# ...

# %%
num_column.head()
# Out:
#    Price  Number of Ratings  Number of Reviews
# 0  34649                  3                  0
# 1  38999                 65                  5
# 2  39999                  8                  1
# 3  69990                  0                  0
# 4  26990                  0                  0

# %%
cat_cloumn.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice   rating
# 0          No       No  2 stars
# ...

# %%
cat_cloumn["brand"].nunique() # number of unique brand ke liye
# Out:
# 8

# %%
cat_cloumn["brand"].unique() # unique brand ka naam aa jayega
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
cat_cloumn["brand"]  # particular column m jana
# Out:
# 0        ASUS
# 1      Lenovo
# 2      Lenovo
# 3        ASUS
# 4        ASUS
#         ...
# 818      ASUS
# 819      ASUS
# 820      ASUS
# 821      ASUS
# 822    Lenovo
# Name: brand, Length: 823, dtype: object

# %%
cat_cloumn["processor_brand"].unique() # processor brand ki unique value dega
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
cat_cloumn["processor_gnrtn"].unique() # process
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
cat_cloumn["processor_name"].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
cat_cloumn["processor_brand"].nunique()
# Out:
# 3

# %%
cat_cloumn["processor_gnrtn"].nunique()
# Out:
# 8

# %%
cat_cloumn["processor_name"].nunique()
# Out:
# 11

# %%
cat_cloumn["os"].nunique()
# Out:
# 3

# %%
cat_cloumn["graphic_card_gb"].nunique()
# Out:
# 5

# %%
num_column["Number of Ratings"].unique()
# Out:
# array([    3,    65,     8,     0,    31,  1946,   259,   425,  1120,
#          286,    58,     7, 15279,   311,    47,    37,  2080,  1479,
#           67,   273,  1267,    14,   284,    44,    33,    10,   816,
#          543,     9,  1178,   299,    20,   758,   634,     4,    17,
#           24,  1753,   216,  1084,    19,   106,    42,  1029,    53,
#           48,    61,    97,   181,   529,  5205,  1090,     1,    70,
#          632,    71,   990,   158,   681,   130,    30,     6,   174,
#           40,    13,   184,  1296,   571,  2551,    35,   118,   245,
#         2058,   117,    74,    39,    29,    43,   984,   523,  1605,
#         4008,  1869,  1278,   143,    28,  2124,   276,   250,  1917,
#         4999,  4203,    15,   527,   103,   324,    69,    16,    12,
#         1146,  1850,   231,   502,  1096,   313,   265,    38,   818,
#           25,   974,    83,   637,   207,   844,    62,   724,    56,
# ...

# %%
num_column["Number of Ratings"].nunique()
# Out:
# 282

# %%
df['brand'].value_counts() # isse hum particular features ke andr brand ki sare name or unki count aa jayega
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
apple=df[df["brand"]=="APPLE"]     # particular brand ke andar ek brand ka row nikalana

# %%
apple
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# ...

# %%
apple.info() # apple ka pura information aa jayega
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, 309 to 622
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              28 non-null     object
#  1   processor_brand    28 non-null     object
#  2   processor_name     28 non-null     object
#  3   processor_gnrtn    28 non-null     object
#  4   ram_gb             28 non-null     object
#  5   ram_type           28 non-null     object
#  6   ssd                28 non-null     object
#  7   hdd                28 non-null     object
#  8   os                 28 non-null     object
#  9   os_bit             28 non-null     object
#  10  graphic_card_gb    28 non-null     object
#  11  weight             28 non-null     object
#  12  warranty           28 non-null     object
#  13  Touchscreen        28 non-null     object
#  14  msoffice           28 non-null     object
#  15  Price              28 non-null     int64
# ...

# %%
asus=df[df["brand"]=="ASUS"] # particular brand ke andar ek brand ka row nikalana

# %%
asus
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 817  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# ...

# %%
asus.info() # asus ka pura information aa jayega
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 249 entries, 0 to 821
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              249 non-null    object
#  1   processor_brand    249 non-null    object
#  2   processor_name     249 non-null    object
#  3   processor_gnrtn    249 non-null    object
#  4   ram_gb             249 non-null    object
#  5   ram_type           249 non-null    object
#  6   ssd                249 non-null    object
#  7   hdd                249 non-null    object
#  8   os                 249 non-null    object
#  9   os_bit             249 non-null    object
#  10  graphic_card_gb    249 non-null    object
#  11  weight             249 non-null    object
#  12  warranty           249 non-null    object
#  13  Touchscreen        249 non-null    object
#  14  msoffice           249 non-null    object
#  15  Price              249 non-null    int64
# ...

# %%
apple["processor_brand"].unique() # apple ke andr processor brand ka unique value nikalan
# Out:
# array(['Intel', 'M1'], dtype=object)

# %%
m1=apple[apple["processor_brand"]=="M1"]     # apple ke andar se m1 chip ke laptop nikalna 
m1
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# 607  APPLE              M1             M1            10th   8 GB     DDR4
# 608  APPLE              M1             M1            10th   8 GB     DDR4
# 609  APPLE              M1             M1            10th   8 GB     DDR4
# 610  APPLE              M1             M1            10th   8 GB     DDR4
# ...

# %%
m1_touch_apple=m1[m1["Touchscreen"]=="Yes"]
m1_touch_apple
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
max1=m1["Price"]
# Out:
# the maximum price of apple m1 chip  599     85990
# 600    112990
# 601    104990
# 602    112990
# 603    132990
# 604    104990
# 605     85990
# 606    149990
# 607    125990
# 608    103990
# 609    101990
# 610    104990
# 611    131990
# 612    128990
# 613    184990
# 614    225990
# 615    124990
# 616    104990
# 617    149990
# 618    169990
# 619    225990
# 620    243990
# 621    309990
# 622    225990
# Name: Price, dtype: int64

# %%
maximum_price=max1.max()
print("the maximum price of apple m1 chip ",maximum_price)
# Out:
# the maximum price of apple m1 chip  309990

# %%
m1.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count      24.000000          24.000000          24.000000
# mean   148156.666667        1397.875000         136.041667
# std     58611.963957        2450.439931         227.346217
# min     85990.000000           3.000000           1.000000
# 25%    104990.000000          44.250000           8.000000
# 50%    127490.000000         519.500000          57.500000
# 75%    173740.000000         682.250000          75.250000
# max    309990.000000        6725.000000         629.000000

# %%
apple_intel=apple[apple["processor_brand"]=="Intel"]

# %%
apple_intel_rgb=apple_intel[apple_intel["ram_gb"]>="8 GB"]
apple_intel_rgb
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
#
#         ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# 309  512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 310  512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
#
#     msoffice   Price   rating  Number of Ratings  Number of Reviews
# 309       No  159990  4 stars                 32                  5
# 310       No  172090  4 stars                108                 13

# %%
apple_intel_rgb_price=apple_intel_rgb[apple_intel_rgb["Price"]<= 100000]
apple_intel_rgb_price
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
asus_proc10=asus[asus["processor_gnrtn"]=="10th"]
asus_proc10
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 27   ASUS           Intel        Core i3            10th   8 GB     DDR4
# 60   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 70   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 86   ASUS           Intel        Core i3            10th   8 GB     DDR4
# 89   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 98   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 119  ASUS           Intel        Core i3            10th   4 GB     DDR4
# 120  ASUS           Intel        Core i3            10th   4 GB     DDR4
# 122  ASUS           Intel        Core i3            10th   4 GB     DDR4
# ...

# %%
asus_proc10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, 0 to 598
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              58 non-null     object
#  1   processor_brand    58 non-null     object
#  2   processor_name     58 non-null     object
#  3   processor_gnrtn    58 non-null     object
#  4   ram_gb             58 non-null     object
#  5   ram_type           58 non-null     object
#  6   ssd                58 non-null     object
#  7   hdd                58 non-null     object
#  8   os                 58 non-null     object
#  9   os_bit             58 non-null     object
#  10  graphic_card_gb    58 non-null     object
#  11  weight             58 non-null     object
#  12  warranty           58 non-null     object
#  13  Touchscreen        58 non-null     object
#  14  msoffice           58 non-null     object
#  15  Price              58 non-null     int64
# ...

# %%
asus_proc10_ramddr3=asus_proc10[asus_proc10["ram_type"]=="LPDDR3"]
asus_proc10_ramddr3
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 302  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 381  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 382  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 386  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 541  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 565  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 566  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 568  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 576  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
#
#          ssd   hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 302   512 GB  0 GB  Windows  64-bit            0 GB  Casual       1 year
# 381   512 GB  0 GB  Windows  64-bit            2 GB  Casual       1 year
# ...

# %%
asus_proc10_ramddr3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 302 to 576
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              9 non-null      object
#  1   processor_brand    9 non-null      object
#  2   processor_name     9 non-null      object
#  3   processor_gnrtn    9 non-null      object
#  4   ram_gb             9 non-null      object
#  5   ram_type           9 non-null      object
#  6   ssd                9 non-null      object
#  7   hdd                9 non-null      object
#  8   os                 9 non-null      object
#  9   os_bit             9 non-null      object
#  10  graphic_card_gb    9 non-null      object
#  11  weight             9 non-null      object
#  12  warranty           9 non-null      object
#  13  Touchscreen        9 non-null      object
#  14  msoffice           9 non-null      object
#  15  Price              9 non-null      int64
# ...

# %%
asus_proc10_ramddr3_oswindow=asus_proc10_ramddr3[asus_proc10_ramddr3["os"]=="Windows"]
asus_proc10_ramddr3_oswindow
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 302  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 381  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 382  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 386  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 541  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 565  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 566  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 568  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 576  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
#
#          ssd   hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 302   512 GB  0 GB  Windows  64-bit            0 GB  Casual       1 year
# 381   512 GB  0 GB  Windows  64-bit            2 GB  Casual       1 year
# ...

# %%
asus_proc10_ramddr3_oswindow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 302 to 576
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              9 non-null      object
#  1   processor_brand    9 non-null      object
#  2   processor_name     9 non-null      object
#  3   processor_gnrtn    9 non-null      object
#  4   ram_gb             9 non-null      object
#  5   ram_type           9 non-null      object
#  6   ssd                9 non-null      object
#  7   hdd                9 non-null      object
#  8   os                 9 non-null      object
#  9   os_bit             9 non-null      object
#  10  graphic_card_gb    9 non-null      object
#  11  weight             9 non-null      object
#  12  warranty           9 non-null      object
#  13  Touchscreen        9 non-null      object
#  14  msoffice           9 non-null      object
#  15  Price              9 non-null      int64
# ...

# %%
asus_proc10_ramddr3_oswindow_graphic4gb=asus_proc10_ramddr3_oswindow[asus_proc10_ramddr3_oswindow["graphic_card_gb"]=="4 GB"]

# %%
asus_proc10_ramddr3_oswindow_graphic4gb
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
asus_proc10_ramddr3_oswindow_graphic4gb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              0 non-null      object
#  1   processor_brand    0 non-null      object
#  2   processor_name     0 non-null      object
#  3   processor_gnrtn    0 non-null      object
#  4   ram_gb             0 non-null      object
#  5   ram_type           0 non-null      object
#  6   ssd                0 non-null      object
#  7   hdd                0 non-null      object
#  8   os                 0 non-null      object
#  9   os_bit             0 non-null      object
#  10  graphic_card_gb    0 non-null      object
#  11  weight             0 non-null      object
#  12  warranty           0 non-null      object
#  13  Touchscreen        0 non-null      object
#  14  msoffice           0 non-null      object
#  15  Price              0 non-null      int64
# ...

# %%
# brand acer proces=intel, ram =8gb, ssd> 512,os=window,grapcard=4card,tuchscreen=yes

# %%
df["brand"].value_counts()
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
acer=df[df["brand"]=="acer"]
acer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 9 to 794
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              51 non-null     object
#  1   processor_brand    51 non-null     object
#  2   processor_name     51 non-null     object
#  3   processor_gnrtn    51 non-null     object
#  4   ram_gb             51 non-null     object
#  5   ram_type           51 non-null     object
#  6   ssd                51 non-null     object
#  7   hdd                51 non-null     object
#  8   os                 51 non-null     object
#  9   os_bit             51 non-null     object
#  10  graphic_card_gb    51 non-null     object
#  11  weight             51 non-null     object
#  12  warranty           51 non-null     object
#  13  Touchscreen        51 non-null     object
#  14  msoffice           51 non-null     object
#  15  Price              51 non-null     int64
# ...

# %%
acer_intel=acer[acer["processor_brand"]=='Intel']
acer_intel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 31 to 628
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              36 non-null     object
#  1   processor_brand    36 non-null     object
#  2   processor_name     36 non-null     object
#  3   processor_gnrtn    36 non-null     object
#  4   ram_gb             36 non-null     object
#  5   ram_type           36 non-null     object
#  6   ssd                36 non-null     object
#  7   hdd                36 non-null     object
#  8   os                 36 non-null     object
#  9   os_bit             36 non-null     object
#  10  graphic_card_gb    36 non-null     object
#  11  weight             36 non-null     object
#  12  warranty           36 non-null     object
#  13  Touchscreen        36 non-null     object
#  14  msoffice           36 non-null     object
#  15  Price              36 non-null     int64
# ...

# %%
acer_intel_ram8=acer_intel[acer["ram_gb"]=="8 GB"]
acer_intel_ram8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 31 to 448
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              25 non-null     object
#  1   processor_brand    25 non-null     object
#  2   processor_name     25 non-null     object
#  3   processor_gnrtn    25 non-null     object
#  4   ram_gb             25 non-null     object
#  5   ram_type           25 non-null     object
#  6   ssd                25 non-null     object
#  7   hdd                25 non-null     object
#  8   os                 25 non-null     object
#  9   os_bit             25 non-null     object
#  10  graphic_card_gb    25 non-null     object
#  11  weight             25 non-null     object
#  12  warranty           25 non-null     object
#  13  Touchscreen        25 non-null     object
#  14  msoffice           25 non-null     object
#  15  Price              25 non-null     int64
# ...

# %%
acer_intel_ram8_ssd512=acer_intel_ram8[acer_intel_ram8["ssd"]<"512GB"]
acer_intel_ram8_ssd512.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 31 to 448
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              25 non-null     object
#  1   processor_brand    25 non-null     object
#  2   processor_name     25 non-null     object
#  3   processor_gnrtn    25 non-null     object
#  4   ram_gb             25 non-null     object
#  5   ram_type           25 non-null     object
#  6   ssd                25 non-null     object
#  7   hdd                25 non-null     object
#  8   os                 25 non-null     object
#  9   os_bit             25 non-null     object
#  10  graphic_card_gb    25 non-null     object
#  11  weight             25 non-null     object
#  12  warranty           25 non-null     object
#  13  Touchscreen        25 non-null     object
#  14  msoffice           25 non-null     object
#  15  Price              25 non-null     int64
# ...

# %%
acer_intel_ram8_ssd512_oswindow=acer_intel_ram8_ssd512[acer_intel_ram8_ssd512["os"]=="Windows"]
acer_intel_ram8_ssd512_oswindow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 31 to 448
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              24 non-null     object
#  1   processor_brand    24 non-null     object
#  2   processor_name     24 non-null     object
#  3   processor_gnrtn    24 non-null     object
#  4   ram_gb             24 non-null     object
#  5   ram_type           24 non-null     object
#  6   ssd                24 non-null     object
#  7   hdd                24 non-null     object
#  8   os                 24 non-null     object
#  9   os_bit             24 non-null     object
#  10  graphic_card_gb    24 non-null     object
#  11  weight             24 non-null     object
#  12  warranty           24 non-null     object
#  13  Touchscreen        24 non-null     object
#  14  msoffice           24 non-null     object
#  15  Price              24 non-null     int64
# ...

# %%
acer_intel_ram8_ssd512_oswindow_gr4gb=acer_intel_ram8_ssd512_oswindow[acer_intel_ram8_ssd512_oswindow["graphic_card_gb"]=="4 GB"]
acer_intel_ram8_ssd512_oswindow_gr4gb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 196 to 325
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              2 non-null      object
#  1   processor_brand    2 non-null      object
#  2   processor_name     2 non-null      object
#  3   processor_gnrtn    2 non-null      object
#  4   ram_gb             2 non-null      object
#  5   ram_type           2 non-null      object
#  6   ssd                2 non-null      object
#  7   hdd                2 non-null      object
#  8   os                 2 non-null      object
#  9   os_bit             2 non-null      object
#  10  graphic_card_gb    2 non-null      object
#  11  weight             2 non-null      object
#  12  warranty           2 non-null      object
#  13  Touchscreen        2 non-null      object
#  14  msoffice           2 non-null      object
#  15  Price              2 non-null      int64
# ...

# %%
acer_intel_ram8_ssd512_oswindow_gr4gb_touch=acer_intel_ram8_ssd512_oswindow_gr4gb[acer_intel_ram8_ssd512_oswindow_gr4gb["Touchscreen"]=="Yes"]

# %%
acer_intel_ram8_ssd512_oswindow_gr4gb_touch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              0 non-null      object
#  1   processor_brand    0 non-null      object
#  2   processor_name     0 non-null      object
#  3   processor_gnrtn    0 non-null      object
#  4   ram_gb             0 non-null      object
#  5   ram_type           0 non-null      object
#  6   ssd                0 non-null      object
#  7   hdd                0 non-null      object
#  8   os                 0 non-null      object
#  9   os_bit             0 non-null      object
#  10  graphic_card_gb    0 non-null      object
#  11  weight             0 non-null      object
#  12  warranty           0 non-null      object
#  13  Touchscreen        0 non-null      object
#  14  msoffice           0 non-null      object
#  15  Price              0 non-null      int64
# ...

# %%
print(df[(df["brand"]=="acer") & (df["Touchscreen"] == "Yes") & (df["processor_brand"] == "Intel") & (df["ram_gb"] >= "8 GB") & (df["ssd"] >= "512GB)])
# Out:
#   Cell In[115], line 1
#     print(df[(df["brand"]=="acer") & (df["Touchscreen"] == "Yes") & (df["processor_brand"] == "Intel") & (df["ram_gb"] >= "8 GB") & (df["ssd"] >= "512GB)])
#                                                                                                                                                   ^
# SyntaxError: unterminated string literal (detected at line 1)
